# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import re

# %%
from textblob import TextBlob
import scipy.stats
import collections

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# import mglearn
# from sklearn.feature_extraction.text import CountVectorizer

# %%
for c in CommentsJan17_df.columns:
    comment_name = c + '_comments.txt'
    CommentsJan17_df[c].to_csv('./Jan2017/'+comment_name, index=False)
    
for c in CommentsJan18_df.columns:
    comment_name = c + '_comments.txt'
    CommentsJan18_df[c].to_csv('./Jan2018/'+comment_name, index=False)
    
for c in CommentsFeb17_df.columns:
    comment_name = c + '_comments.txt'
    CommentsFeb17_df[c].to_csv('./Feb2017/'+comment_name, index=False)
    
for c in CommentsFeb18_df.columns:
    comment_name = c + '_comments.txt'
    CommentsFeb18_df[c].to_csv('./Feb2018/'+comment_name, index=False)
    
for c in CommentsMarch17_df.columns:
    comment_name = c + '_comments.txt'
    CommentsMarch17_df[c].to_csv('./March2017/'+comment_name, index=False)
    
for c in CommentsMarch18_df.columns:
    comment_name = c + '_comments.txt'
    CommentsMarch18_df[c].to_csv('./March2018/'+comment_name, index=False)
    
for c in CommentsApril17_df.columns:
    comment_name = c + '_comments.txt'
    CommentsApril17_df[c].to_csv('./April2017/'+comment_name, index=False)
    
for c in CommentsApril18_df.columns:
    comment_name = c + '_comments.txt'
    CommentsApril18_df[c].to_csv('./April2018/'+comment_name, index=False)
    
for c in CommentsMay17_df.columns:
    comment_name = c + '_comments.txt'
    CommentsMay17_df[c].to_csv('./May2017/'+comment_name, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8bcadda5c5cf> in <module>()
#       1 for c in CommentsJan17_df.columns:
#       2     comment_name = c + '_comments.txt'
# ----> 3     CommentsJan17_df[c].to_csv('./Jan2017/'+comment_name, index=False)
#       4
#       5 for c in CommentsJan18_df.columns:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in to_csv(self, path, index, sep, na_rep, float_format, header, index_label, mode, encoding, date_format, decimal)
#    2686                            index_label=index_label, mode=mode,
#    2687                            encoding=encoding, date_format=date_format,
# -> 2688                            decimal=decimal)
#    2689         if path is None:
#    2690             return result
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1590                 self.writer = csv.writer(f, **writer_kwargs)
#    1591
# -> 1592             self._save()
#    1593
#    1594         finally:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in _save(self)
#    1691                 break
#    1692
# -> 1693             self._save_chunk(start_i, end_i)
#    1694
#    1695     def _save_chunk(self, start_i, end_i):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in _save_chunk(self, start_i, end_i)
#    1717                                         quoting=self.quoting)
#    1718
# -> 1719         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#    1720
#    1721
#
# pandas/_libs/lib.pyx in pandas._libs.lib.write_csv_rows()
#
# KeyboardInterrupt:

# %%
CommentsJan17_df = pd.read_csv("CommentsJan2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesJan17_df = pd.read_csv("ArticlesJan2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
    
CommentsJan18_df = pd.read_csv("CommentsJan2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesJan18_df = pd.read_csv("ArticlesJan2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')

CommentsFeb17_df = pd.read_csv("CommentsFeb2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesFeb17_df = pd.read_csv("ArticlesFeb2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
    
CommentsFeb18_df = pd.read_csv("CommentsFeb2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesFeb18_df = pd.read_csv("ArticlesFeb2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')

CommentsMarch17_df = pd.read_csv("CommentsMarch2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesMarch17_df = pd.read_csv("ArticlesMarch2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')

CommentsMarch18_df = pd.read_csv("CommentsMarch2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesMarch18_df = pd.read_csv("ArticlesMarch2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')

CommentsApril17_df = pd.read_csv("CommentsApril2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesApril17_df = pd.read_csv("ArticlesApril2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')

CommentsApril18_df = pd.read_csv("CommentsApril2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesApril18_df = pd.read_csv("ArticlesApril2018.csv", error_bad_lines=False, index_col=False, dtype='unicode')

CommentsMay17_df = pd.read_csv("CommentsMay2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesMay17_df = pd.read_csv("ArticlesMay2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')

# %%
CommentsAll_df = pd.read_csv("CommentsJan2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
CommentsAll_df.append(CommentsJan18_df)
CommentsAll_df.append(CommentsFeb17_df)
CommentsAll_df.append(CommentsFeb18_df)
CommentsAll_df.append(CommentsMarch17_df)
CommentsAll_df.append(CommentsMarch18_df)
CommentsAll_df.append(CommentsApril17_df)
CommentsAll_df.append(CommentsApril18_df)
CommentsAll_df.append(CommentsMay17_df)
# Out:
#        approveDate                 articleID articleWordCount  \
# 0       1483455908  58691a5795d0e039260788b9             1324
# 1       1483455656  58691a5795d0e039260788b9             1324
# 2       1483455655  58691a5795d0e039260788b9             1324
# 3       1483455653  58691a5795d0e039260788b9             1324
# 4       1483455216  58691a5795d0e039260788b9             1324
# 5       1483415940  58691a5795d0e039260788b9             1324
# 6       1483415765  58691a5795d0e039260788b9             1324
# 7       1483415765  58691a5795d0e039260788b9             1324
# 8       1483415765  58691a5795d0e039260788b9             1324
# 9       1483415499  58691a5795d0e039260788b9             1324
# 10      1483415499  58691a5795d0e039260788b9             1324
# 11      1483415499  58691a5795d0e039260788b9             1324
# 12      1483413566  58691a5795d0e039260788b9             1324
# 13      1483413566  58691a5795d0e039260788b9             1324
# 14      1483411691  58691a5795d0e039260788b9             1324
# 10      Politics. What is it? …to Gain and maintain Po...  20969096.0
# 11      I am retired and medicare is an absolutely ess...  20969083.0
# 12      “It’s a big job to actually have responsibilit...  20969041.0
# 13      One small ray of light in the GOP having full ...  20969036.0
# 14      Repeal Obamacare.  There are too many people g...  20968978.0
# 15      Well, maybe if Obama hadn't made that infernal...  20968969.0
# 16      I will not shed a tear if some of the Obama po...  20968957.0
# 17      Why do I always think of a tortoise when McCon...  20968951.0
# 18       It would be nice if we could have a return to...  20968936.0
# 19      I do not understand why the Senate's refusal t...  20968925.0
# 20      Where I live, we were one of the hardest hit a...  20968884.0
# 21      We are once again at the front line of whats g...  20968868.0
# 22      You consider equality social ills, perhaps in ...  20968862.0
# 23      They should just repeal Obamacare, re-enact it...  20968832.0
# 24      '...“I hear probably more about the strangulat...  20968827.0
# 25      "This is no time for hubris.  You have to perf...  20968826.0
# 26      Enough of the 30,000 foot analysis.  <br/><br/...  20968801.0
# 27                   Repeal and replace Obamacare Please!  20968788.0
# 28      Given that senator Mitch McConnell's face is t...  20968781.0
# 29      The Obama regime represented eight years of so...  20968739.0
# ...                                                   ...         ...
# 276359  @mark<br/><br/>Are you assuming you cracked an...    22715115
# 276360  Anony, that's all fine and good, but more impo...    22713144
# 276361  An actual businessman! Not Trump the imposter ...    22711902
# 276362  If he had run, as Dem or Republican, I would h...    22712533
# 276363  or Jerry Brown    We need unafraid, progressiv...    22715310
# 276364  "But Bloomberg Philanthropies, Mr. Bloomberg’s...    22712822
# 276365  Because most people in this country think Mich...    22711877
# 276366  And Bloomberg is REALLY rich, and a self made ...    22712629
# 276367   @Eric:  Michael Bloomberg isn't president "be...    22716456
# 276368  The US has agreed to pay $3 billion total into...    22711999
# 276369  "I'd say, if it were a Democrat who decided to...    22716160
# 276370  As Noam Chomsky said: " the Republican Party i...    22711925
# 276371  Don't own JPM shares or conduct any business w...    22712182
# 276372  Improve vehicle emissions standards? See below...    22714994
# 276373  Does this include China and India both some of...    22715334
# 276374  What's even more simple is that you are defend...    22721946
# 276375  Sorry, but trying to have a serious debate wit...    22711760
# 276376  Believe me I've tried to have serious discussi...    22713428
# 276377  True. <br/><br/>Which means that it's only pos...    22715420
# 276378  ..... and we've now heard from the bah humbug ...    22712684
# 276379  "most of the people complaining about this are...    22713198
# 276380  @Sue - Thank you!<br/><br/>I was wondering whe...    22716097
# 276381  Be careful - the minions of rural Pennsylvania...    22713697
# 276382  As a non-white immigrant, I am actually scared...    22713932
# 276383  I follow the same policy. Not willing to give ...    22714984
# 276384  C'mon Connecticut...let's add ourselves to the...    22713248
# 276385  Write or call Hickenlooper's office! It was on...    22715167
# 276386     C'mon North Carolina! -- oh, who am I kidding.    22716312
# 276387  California is the federal government's #1 "don...    22716238
# 276388                         Or stop Earth First . . .     22711916
#
#        commentSequence commentTitle commentType  createDate depth   ...    \
# 0           20969730.0        <br/>     comment  1483426105   1.0   ...
# 1           20969325.0        <br/>     comment  1483417407   1.0   ...
# 2           20969855.0        <br/>     comment  1483431433   1.0   ...
# 8                    Cesar  65968698.0                       <br/>       NaN
# 9                 Darsan54  24037889.0            Grand Rapids, MI       NaN
# 10          Hubert Daisley  76075664.0                Trinidad W.I       NaN
# 11                 richard  65543878.0                        Guil       NaN
# 12          Margaret Diehl  60501163.0                         NYC       NaN
# 13                M. White  75190681.0             New Orleans, LA       NaN
# 14                 Glennmr    449122.0                Planet Earth       NaN
# 15                     SCA  31275444.0                          NH       NaN
# 16           Girish Kotwal  69024476.0              Louisville, KY       NaN
# 17        Ellen Liversidge  62272639.0                San Diego CA       NaN
# 18                 logodos  17998044.0                    New York       NaN
# 19                P Nelson  62699284.0                      Austin       NaN
# 20                 Susan H  54544961.0                          SC       NaN
# 21              D'town Boy  65796135.0                         Htx       NaN
# 22                      RB  64890360.0             West Palm Beach       NaN
# 23         Madeline Conant  57320526.0                     Midwest       NaN
# 24                     jla  66465803.0                         usa       NaN
# 25                   bstar  69693898.0               Baltimore, MD       NaN
# 26      Alexandra Brockton  19827014.0         Boca Raton, Florida       NaN
# 27              Sue Haynie  64901224.0                     Norwalk       NaN
# 28                    John  41586169.0                   St. Louis       NaN
# 29                Ryan Wei  76162415.0                   Hong Kong       NaN
# ...                    ...         ...                         ...       ...
# 276359              Stuart    43645449                      Boston       NaN
# 276360                Alex    33404271               San Francisco       NaN
# 276361                Lisa    47102908                          CT       NaN
# 276362                Name    47269236                        Here       NaN
# 276363                Zane    39164842                          NY       NaN
# 276364          Humanesque    54991023                    New York       NaN
# 276365                Eric    46926660                  New Jersey       NaN
# 276366                  PM    43786686                         NYC       NaN
# 276367               Julia    56760806                    Bay Area       NaN
# 276368            bounce33    56707819                  West Coast       NaN
# 276369               Annie    17274283                  Pittsburgh       NaN
# 276370             Pushkin    66918161                      Canada       NaN
# 276371               Susan    78014829              Toronto Canada       NaN
# 276372                John    55359661                  Washington       NaN
# 276373                 mar     2115115                          NV       NaN
# 276374              MScott    72749735                     Florida       NaN
# 276375         C. V. Danes    68246165                       <br/>       NaN
# 276376               Vicki    78815519                     Florida       NaN
# 276377           Ana Luisa    32716950                     Belgium       NaN
# 276378       coale johnson    59172341  5000 horseshoe meadow road       NaN
# 276379                 Sue    63351622                Vancouver BC       NaN
# 276380               Annie    17274283                  Pittsburgh       NaN
# 276381               Kevin    71035835                Philadelphia       NaN
# 276382                 SYJ    25487073                         USA       NaN
# 276383          Dbottinick    15485929                  Plainsboro       NaN
# 276384           pmulberry     3771862                Cornwall, CT       NaN
# 276385                geez    63494752                     Boulder       NaN
# 276386                 Liz    28028109                     Raleigh       NaN
# 276387            CarissaV    72050670                       <br/>       NaN
# 276388         Marla Burke    68761350            Mill Valley, Ca.       NaN
#
#        userURL
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ...        ...
# 276359     NaN
# 276360     NaN
# 276361     NaN
# 276362     NaN
# 276363     NaN
# 276364     NaN
# 276365     NaN
# 276366     NaN
# 276367     NaN
# 276368     NaN
# 276369     NaN
# 276370     NaN
# 276371     NaN
# 276372     NaN
# 276373     NaN
# 276374     NaN
# 276375     NaN
# 276376     NaN
# 276377     NaN
# 276378     NaN
# 276379     NaN
# 276380     NaN
# 276381     NaN
# 276382     NaN
# 276383     NaN
# 276384     NaN
# 276385     NaN
# 276386     NaN
# 276387     NaN
# 276388     NaN
#
# [507838 rows x 34 columns]

# %%
CommentsAll_df.head()

# %%
ArticlesAll_df = pd.read_csv("ArticlesJan2017.csv", error_bad_lines=False, index_col=False, dtype='unicode')
ArticlesAll_df.append(ArticlesJan18_df)
ArticlesAll_df.append(ArticlesFeb17_df)
ArticlesAll_df.append(ArticlesFeb18_df)
ArticlesAll_df.append(ArticlesMarch17_df)
ArticlesAll_df.append(ArticlesMarch18_df)
ArticlesAll_df.append(ArticlesApril17_df)
ArticlesAll_df.append(ArticlesApril18_df)
ArticlesAll_df.append(ArticlesMay17_df)
# Out:
#                                               abstract  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23   After losing three limbs in Afghanistan, a Mar...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 966                                                NaN
# 967                                                NaN
# 968                                                NaN
# 969                                                NaN
# 970                                                NaN
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
# 976                                                NaN
# 977                                                NaN
# 978                                                NaN
# 979                                                NaN
# 980                                                NaN
# 981                                                NaN
# 982                                                NaN
# 983                                                NaN
# 984                                                NaN
# 985                                                NaN
# 986                                                NaN
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
# 990                                                NaN
# 991                                                NaN
# 992                                                NaN
# 993                                                NaN
# 994                                                NaN
# 995                                                NaN
#
#                     articleID articleWordCount  \
# 0    58691a5795d0e039260788b9             1324
# 1    586967bf95d0e03926078915             2836
# 2    58698a1095d0e0392607894a              445
# 3    5869911a95d0e0392607894e              864
# 4    5869a61795d0e03926078962              309
# 5    5869afd495d0e0392607896c             2180
# 6    5869d08f95d0e03926078980             1146
# 7    586a0d8795d0e039260789b3              557
# 8    586a0d8795d0e039260789b6              784
# 9    586a32f495d0e039260789f3             1109
# 10   586a4a2a95d0e03926078a0f              533
# 11   586a518a95d0e03926078a18              836
# 12   586ad1fa95d0e03926078ac7             1270
# 13   586af79995d0e03926078ae6              279
# 14   586afcfe95d0e03926078aee             3361
# 15   586b037e95d0e03926078af5              677
# 16   586b0a7495d0e03926078b03             1152
# 17   586b0ba995d0e03926078b05              797
# 18   586b10be95d0e03926078b11              875
# 19   586b13b995d0e03926078b13              638
# 20   586b53e095d0e03926078b52              346
# 21   586b5a8195d0e03926078b5b              108
# 22   586b5ef495d0e03926078b68              805
# 23   586b689c95d0e03926078b75              769
# 24   586b763095d0e03926078b91             8022
# 25   586b762c95d0e03926078b8f             1288
# 26   586b763e95d0e03926078b93             2350
# 27   586b855895d0e03926078baf             1049
# 28   586b924d95d0e03926078bc5              963
# 29   586b94c695d0e03926078bc9              289
# ..                        ...              ...
# 966  592f918b7c459f24986e2bce             2447
# 967  592fade37c459f24986e2c0d              121
# 968  592fb2047c459f24986e2c15              356
# 969  592fc0667c459f24986e2c2e              714
# 970  592fc07c7c459f24986e2c31              826
# 971  592fc07c7c459f24986e2c32              784
# 972  592fc8357c459f24986e2c43             2069
# 973  592fd09c7c459f24986e2c5b              246
# 974  592fd79c7c459f24986e2c6f              662
# 975  592fd7b87c459f24986e2c75             1150
# 976  592fe7087c459f24986e2cab             1193
# 977  59301bf97c459f24986e2d43             1209
# 978  59302c097c459f24986e2d75             1662
# 979  593036757c459f24986e2daa              395
# 980  5930379e7c459f24986e2daf              178
# 981  593039197c459f24986e2db2              231
# 982  593045e47c459f24986e2de4              207
# 983  593056f17c459f24986e2e1b              791
# 984  5930616f7c459f24986e2e41             1474
# 985  59306dfd7c459f24986e2e6e              999
# 986  5930707f7c459f24986e2e7d              434
# 987  5930707f7c459f24986e2e7c             1304
# 988  593072d27c459f24986e2e83              653
# 989  59307a537c459f24986e2ea5             1171
# 990  593081c47c459f24986e2ebd              935
# 991  593087d17c459f24986e2ed8              609
# 992  59308fdc7c459f24986e2ef2              797
# 993  5930a48f7c459f24986e2f24              945
# 994  5930aa877c459f24986e2f2a              141
# 995  5930ae877c459f24986e2f33             1176
#
#                                               byline documentType  \
# 0                             By JENNIFER STEINHAUER      article
# 1                                    By MARK LANDLER      article
# 2                                By CAITLIN LOVINGER      article
# 3                                  By JOCHEN BITTNER      article
# 4                                     By JIAYIN SHEN      article
# 5                                  By MICHAEL POWELL      article
# 6                                       By MIKE HALE      article
# 7                             By THE EDITORIAL BOARD      article
# 8                                    By PAUL KRUGMAN      article
# 9                                   By JANE E. BRODY      article
# 10                                   By VANESSA PIAO      article
# 11                               By AARON E. CARROLL      article
# 12                                By DAVID WALDSTEIN      article
# 13                                  By ROBIN RIDLESS      article
# 14                 By ABBY GOODNOUGH and ROBERT PEAR      article
# 15                            By THE EDITORIAL BOARD      article
# 16                                    By ERIC LIPTON      article
# 17                                By ALISSA J. RUBIN      article
# 18   By EZRA LEVIN, LEAH GREENBERG and ANGEL PADILLA      article
# 19                               By CAITLIN LOVINGER      article
# 20                                  By GERRY MULLANY      article
# 21                             By KATHERINE SCHULTEN      article
# 22                                   By DAVID BROOKS      article
# 23                                   By JAMES ESTRIN     blogpost
# 24                                   By JON MOOALLEM      article
# 25                                   By BEVERLY GAGE      article
# 26                                    By ELLEN BARRY      article
# 27                                 By JONATHAN WOLFE      article
# 28                                By LESLEY ALDERMAN      article
# 29                                  By SHANNON DOYNE      article
# ..                                               ...          ...
# 966                                By JASON HOROWITZ      article
# 967                            By KATHERINE SCHULTEN      article
# 968                                    By LUO SILING      article
# 969                           By THE EDITORIAL BOARD      article
# 970                                  By GAIL COLLINS      article
# 971                               By CHARLES M. BLOW      article
# 972                              By THOMAS B. EDSALL      article
# 973                                 By SHANNON DOYNE      article
# 974                       By CAROLINE CROSSON GILPIN      article
# 975                               By DAVID E. SANGER      article
# 976                                By JONATHAN WOLFE      article
# 977                                By ANDREW HIGGINS      article
# 978                                By DENNIS OVERBYE      article
# 979                                  By DAVID GELLES      article
# 980                              By RONI CARYN RABIN      article
# 981                              By RONI CARYN RABIN      article
# 982                                  By SUSAN LEHMAN      article
# 983        By MICHAEL GONCHAR and KATHERINE SCHULTEN      article
# 991  Yes, You Can Write More Than One Letter in a S...
# 992             Trump’s Act  Of Gratuitous Destruction
# 993                         Petty Crime, Daunting Bail
# 994                                            Unknown
# 995  Bucking Trump, These Cities, States and Compan...
#
#                                               keywords multimedia  \
# 0    ['United States Politics and Government', 'Law...          1
# 1    ['Obama, Barack', 'Afghanistan', 'United State...          1
# 2    ['Crossword Puzzles', 'Boxing Day', 'Holidays ...          1
# 3    ['Cyberwarfare and Defense', 'Presidential Ele...          1
# 4        ['Shoes and Boots', 'Buses', 'New York City']          0
# 5    ['Coaches and Managers', 'Education (K-12)', '...          1
# 6            ['Television', 'The Affair (TV Program)']          1
# 7    ['Trump, Donald J', 'Son, Masayoshi', 'Wireles...          1
# 8    ['Trump, Donald J', 'United States Politics an...          1
# 9    ['Adams, Eric L', 'Diabetes', 'Diet and Nutrit...          1
# 10   ['Transgender and Transsexuals', 'Mr C', 'Disc...          1
# 11                   ['Cryotherapy', 'Tissue (Human)']          1
# 12   ['Doping (Sports)', 'Baseball', 'Baseball Hall...          1
# 13   ['Holidays and Special Occasions', 'Plaza Hote...          0
# 14   ['Health Insurance and Managed Care', 'Patient...          1
# 15   ['Government Employees', 'United States Politi...          1
# 16   ['House of Representatives', 'House Committee ...          1
# 17   ['France', 'Work-Life Balance', 'E-Mail', 'Law...          0
# 18   ['Tea Party Movement', 'Democratic Party', 'Ho...          1
# 19                               ['Crossword Puzzles']          1
# 20   ['Air Pollution', 'Beijing (China)', 'Video Re...          1
# 21                                                  []          1
# 22   ['Trump, Donald J', 'United States Politics an...          1
# 23   ['Bitzer, Kirsten', 'Colorado', 'United States...          1
# 24   ['Death and Dying', 'Miller, BJ (1971- )', 'Ze...          1
# 25   ['Presidential Election of 2016', 'United Stat...          1
# 26   ['India', 'Telephones and Telecommunications',...          1
# 27                                   ['New York City']          1
# 28   ['Psychology and Psychologists', 'Pessimism', ...          1
# 29                                                  []          1
# ..                                                 ...        ...
# 966           ['Travel and Vacations', 'Rome (Italy)']          3
# 967                                                 []          3
# 968  ['vis-photo', 'Demonstrations, Protests and Ri...          3
# 969  ['United States Politics and Government', 'Eth...          3
# 970  ['United States Politics and Government', 'Kus...          3
# 971  ['Comey, James B', 'Presidential Election of 2...          3
# 972  ['United States Politics and Government', 'Pre...          3
# 973  ['News and News Media', 'New York Times', 'Rea...          3
# 974  ['Cheating', 'Computers and the Internet', 'Co...          3
# 975  ['United States Politics and Government', 'Tru...          3
# 976            ['Ferries', 'Beaches', 'New York City']          3
# 977  ['Cyberwarfare and Defense', 'Presidential Ele...          3
# 978  ['Black Holes (Space)', 'Laser Interferometer ...          3
# 979  ['Meditation', 'Parenting', 'Families and Fami...          3
# 980  ['Anaphylactic Shock', 'Food', 'Allergies', 'N...          3
# 981  ['Arthritis', 'Pain-Relieving Drugs', 'Knees',...          3
# 982  ['Podcasts', 'The Daily (Radio Program)', 'New...          3
# 983                                                 []          3
# 984  ['United Nations Framework Convention on Clima...          3
# 985  ['United Nations Framework Convention on Clima...         67
# 3  ['Cyberwarfare and Defense', 'Presidential Ele...          1      OpEd
# 4      ['Shoes and Boots', 'Buses', 'New York City']          0     Metro
#
#   printPage              pubDate   sectionName  \
# 0         1  2017-01-01 15:03:38      Politics
# 1         1  2017-01-01 20:34:00  Asia Pacific
# 2         0  2017-01-01 23:00:24       Unknown
# 3        15  2017-01-01 23:30:27       Unknown
# 4        12  2017-01-02 01:00:02       Unknown
#
#                                              snippet              source  \
# 0  The most powerful and ambitious Republican-led...  The New York Times
# 1  A strategy that went from a “good war” to the ...  The New York Times
# 2            Chuck Deodene puts us in a bubbly mood.  The New York Times
# 3  With a friend entering the White House, Vladim...  The New York Times
# 4    Witnessing an act of generosity on a rainy day.  The New York Times
#
#   typeOfMaterial                                             webURL  \
# 0           News  https://www.nytimes.com/2017/01/01/us/politics...
# 1           News  https://www.nytimes.com/2017/01/01/world/asia/...
# 2           News  https://www.nytimes.com/2017/01/01/crosswords/...
# 3          Op-Ed  https://www.nytimes.com/2017/01/01/opinion/ang...
# 4          Brief  https://www.nytimes.com/2017/01/01/nyregion/me...
#
#   articleWordCount
# 0             1324
# 1             2836
# 2              445
# 3              864
# 4              309

# %%
def findHeadlinePolarity(row):
    blob = TextBlob(row['headline'])
    return blob.sentiment.polarity

def findHeadlineSubjectivity(row):
    blob = TextBlob(row['headline'])
    return blob.sentiment.subjectivity

def findSnippetPolarity(row):
    blob = TextBlob(row['snippet'])
    return blob.sentiment.polarity

def findSnippetSubjectivity(row):
    blob = TextBlob(row['snippet'])
    return blob.sentiment.subjectivity

def readSnippet(row):
    text = TextBlob(row['snippet'])
    words = text.split(' ')
    counter = dict(collections.Counter(words))
    return counter

def findSnippetEntropy(row):
    counter = readSnippet(row)
    counts = np.array(list(counter.values()))
    entropy = scipy.stats.entropy(counts, base=2)
    return entropy

# %%
ArticlesAll_df['HeadlinePolarity'] = ArticlesAll_df.apply (lambda row: findHeadlinePolarity(row),axis=1)
ArticlesAll_df['HeadlineSubjectivity'] = ArticlesAll_df.apply (lambda row: findHeadlineSubjectivity(row),axis=1)

ArticlesAll_df['SnippetPolarity'] = ArticlesAll_df.apply (lambda row: findSnippetPolarity(row),axis=1)
ArticlesAll_df['SnippetSubjectivity'] = ArticlesAll_df.apply (lambda row: findSnippetSubjectivity(row),axis=1)
ArticlesAll_df['SnippetEntropy'] = ArticlesAll_df.apply (lambda row: findSnippetEntropy(row),axis=1)

# %%
snippets = {}

for i in range(20):
    if ArticlesAll_df["newDesk"][i] in snippets.keys():
        snippets[ArticlesAll_df["newDesk"][i]] = snippets[ArticlesAll_df["newDesk"][i]].join(ArticlesAll_df['snippet'][i])
    else:
        snippets[ArticlesAll_df["newDesk"][i]] = ArticlesAll_df['snippet'][i]

# %%
snippets2 = {}

for i in range(500, 520):
    if ArticlesAll_df["newDesk"][i] in snippets2.keys():
        snippets2[ArticlesAll_df["newDesk"][i]] = snippets2[ArticlesAll_df["newDesk"][i]].join(ArticlesAll_df['snippet'][i])
    else:
        snippets2[ArticlesAll_df["newDesk"][i]] = ArticlesAll_df['snippet'][i]

# %%
snippets3 = {}

for i in range(700, 720):
    if ArticlesAll_df["newDesk"][i] in snippets3.keys():
        snippets3[ArticlesAll_df["newDesk"][i]] = snippets3[ArticlesAll_df["newDesk"][i]].join(ArticlesAll_df['snippet'][i])
    else:
        snippets3[ArticlesAll_df["newDesk"][i]] = ArticlesAll_df['snippet'][i]

# %%
snippets4 = {}

for i in range(200, 220):
    if ArticlesAll_df["newDesk"][i] in snippets4.keys():
        snippets4[ArticlesAll_df["newDesk"][i]] = snippets4[ArticlesAll_df["newDesk"][i]].join(ArticlesAll_df['snippet'][i])
    else:
        snippets4[ArticlesAll_df["newDesk"][i]] = ArticlesAll_df['snippet'][i]

# %%
counter =

# %%
def findCounter(text):
    text = re.sub(r'\W+', ' ',text)
    words = text.split(' ')
    counter = dict(collections.Counter(words))
    return counter

def findEntropy(text):
    counter = findCounter(text)
    counts = np.array(list(counter.values()))
    entropy = scipy.stats.entropy(counts, base=2)
    return entropy

# def findEntropiesWithCounter(counter):
#     entropies = dict()
#     for k in snippets.keys():
#         entropies[k] = findEntropy(str(snippets[k]))
#     return entropies
#     counts = np.array(list(counter.values()))
#     entropy = scipy.stats.entropy(counts, base=2)
#     return entropy

def findEntropies(snippets):
    entropies = dict()
    for k in snippets.keys():
        entropies[k] = findEntropy(str(snippets[k]))
    return entropies

findEntropies(snippets)

# %%
from collections import Counter

counter = Counter(findCounter(str(snippets)))
counter2 = Counter(findCounter(str(snippets2)))
counter3 = Counter(findCounter(str(snippets3)))

# %%
counterAll = counter + counter2 + counter3

# %%
print(counterAll)
# findEntropiesWithCounter(dict(counterAll))
# Out:
# Counter({'of': 1880410, 'is': 1598755, 'rough': 1577928, 'translation': 1577928, 'America': 1577928, 'First': 1577928, 'Muslims': 1577928, 'last': 1577928, 'the': 618520, 'to': 322438, 'A': 276712, 'are': 270777, 'march': 250194, 'shows': 250194, 'why': 250194, 'identity': 250194, 'politics': 250194, 'central': 250194, 'future': 250194, 'Democratic': 250194, 'Party': 250194, 'eA': 171750, 'tA': 149046, 'iA': 115137, 'hA': 114108, 'aA': 103491, 'rA': 103197, 's': 79908, 'oA': 69582, 'in': 68876, 'sA': 68553, 'nA': 58524, 'dA': 57936, 'cA': 57201, 'lA': 57054, 'The': 54035, 'most': 52642, 'a': 50941, 'good': 43218, 'that': 42189, 'mA': 34644, 'yA': 34497, 'eThe': 33757, 'about': 32023, 'and': 31073, 'on': 28527, 'for': 26753, 'clear': 26411, 'President': 26275, 'powerful': 26274, 'ambitious': 26274, 'Republican': 26274, 'led': 26274, 'Congress': 26274, '20': 26274, 'years': 26274, 'plans': 26274, 'quick': 26274, 'action': 26274, 'several': 26274, 'priorities': 26274, 'notably': 26274, 'path': 26274, 'repeal': 26274, 'Obama': 26274, 'health': 26274, 'care': 26274, 'law': 26274, 'what': 23756, 'uA': 22998, 'his': 22785, 'vA': 22704, 'kA': 22704, 'with': 21748, 'from': 21745
': 207, 'aTThe': 207, 'iVATs': 180, 'uAA': 176, 'pAA': 176, 'yAA': 176, 'RThe': 174, 'CThe': 174, 'oWith': 171, 'tWith': 171, 'place': 150, 'poverty': 150, 'social': 150, 'ills': 150, 'fractured': 150, 'families': 150, 'Raul': 150, 'Mendoza': 150, '69': 150, 'coach': 150, 'Chinle': 150, 'Ariz': 150, 'Wildcats': 150, 'source': 150, 'quiet': 150, 'strength': 150, 'young': 150, 'players': 150, 'lVATs': 15 ...

# %%
findEntropies(snippets2)
# Out:
# {'Business': 4.5465935642949384,
#  'Editorial': 4.3923174227787589,
#  'Foreign': 4.5016291673878248,
#  'Insider': 4.1429146733542526,
#  'Learning': 4.1022457306877458,
#  'Metro': 4.7471773163691013,
#  'National': 4.7044997731131657,
#  'OpEd': 4.0440569408206812,
#  'Politics': 4.2776134368191157,
#  'Unknown': 5.0374011976541118,
#  'Weekend': 4.4594316186372964,
#  'Well': 4.4306324094907481}

# %%
findEntropies(snippets3)
# Out:
# {'Business': 4.6438561897747244,
#  'Culture': 4.6237832639065415,
#  'Dining': 4.169925001442313,
#  'Insider': 3.8073549220576033,
#  'Metro': 3.8073549220576033,
#  'National': 4.8140958526974673,
#  'OpEd': 3.6179201603841564,
#  'Science': 3.9332391779903171,
#  'Sports': 4.4820814890068341,
#  'SundayBusiness': 4.6644977792004605,
#  'Unknown': 3.3721775605905231}

# %%
findEntropies(snippets4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3c30683257e0> in <module>()
# ----> 1 findEntropies(snippets4)
#
# <ipython-input-13-3942980356dd> in findEntropies(snippets)
#      14     entropies = dict()
#      15     for k in snippets.keys():
# ---> 16         entropies[k] = findEntropy(str(snippets[k]))
#      17     return entropies
#      18
#
# <ipython-input-13-3942980356dd> in findEntropy(text)
#       6
#       7 def findEntropy(text):
# ----> 8     counter = findCounter(text)
#       9     counts = np.array(list(counter.values()))
#      10     entropy = scipy.stats.entropy(counts, base=2)
#
# <ipython-input-13-3942980356dd> in findCounter(text)
#       2     text = re.sub(r'\W+', ' ',text)
#       3     words = text.split(' ')
# ----> 4     counter = dict(collections.Counter(words))
#       5     return counter
#       6
#
# ~/miniconda3/lib/python3.6/collections/__init__.py in __init__(*args, **kwds)
#     535             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     536         super(Counter, self).__init__()
# --> 537         self.update(*args, **kwds)
#     538
#     539     def __missing__(self, key):
#
# ~/miniconda3/lib/python3.6/collections/__init__.py in update(*args, **kwds)
#     622                     super(Counter, self).update(iterable) # fast path when counter is empty
#     623             else:
# --> 624                 _count_elements(self, iterable)
#     625         if kwds:
#     626             self.update(kwds)
#
# KeyboardInterrupt:

# %%
newDesk_group_dict = {}

for i in range(len(ArticlesAll_df)):
    if ArticlesAll_df["newDesk"][i] in newDesk_group_dict.keys():
        newDesk_group_dict[ArticlesAll_df["newDesk"][i]] += 1
    else:
        newDesk_group_dict.setdefault(ArticlesAll_df["newDesk"][i], 1)
newDesk_group_dict

# %%
newDesk_group_list = list(newDesk_group_dict.items())
newDesk_group_list.sort(key=lambda x: x[1], reverse=True)

# %%
x = []
y = []

for i in range(len(newDesk_group_list)):
    x.append(newDesk_group_list[i][0])
    y.append(newDesk_group_list[i][1])

# %%
plt.close()
plt.figure(figsize=(10, 10))
plt.title("Number of Articles per Category")
plt.xlabel("Category")
plt.ylabel("Number of articles")
plt.xticks(rotation=90)
sns.barplot(x, y)
plt.show()
# plt.savefig("Category-articles.png")

# %%
comments_newDesk_group_dict = {}

for i in range(len(CommentsAll_df)):
    if CommentsAll_df["newDesk"][i] in comments_newDesk_group_dict.keys():
        comments_newDesk_group_dict[CommentsAll_df["newDesk"][i]] += 1
    else:
        comments_newDesk_group_dict.setdefault(CommentsAll_df["newDesk"][i], 1)

comments_newDesk_group_dict
# Out:
# {'BookReview': 12,
#  'Business': 4689,
#  'Culture': 3187,
#  'Dining': 1950,
#  'EdLife': 876,
#  'Editorial': 23437,
#  'Foreign': 11096,
#  'Games': 2105,
#  'Insider': 858,
#  'Learning': 4673,
#  'Letters': 39,
#  'Magazine': 5200,
#  'Metro': 2228,
#  'Metropolitan': 816,
#  'National': 72331,
#  'OpEd': 78957,
#  'Podcasts': 38,
#  'Politics': 1151,
#  'RealEstate': 155,
#  'Science': 4166,
#  'Sports': 2061,
#  'Styles': 50,
#  'SundayBusiness': 525,
#  'Travel': 538,
#  'Unknown': 3596,
#  'Upshot': 5075,
#  'Weekend': 154,
#  'Well': 1486}

# %%
comments_newDesk_group_list = list(comments_newDesk_group_dict.items())
comments_newDesk_group_list.sort(key=lambda x: x[1], reverse=True)

# %%
# Let's take a look at comments_newDesk_group_dict
comments_newDesk_group_dict
# Out:
# {'BookReview': 12,
#  'Business': 4689,
#  'Culture': 3187,
#  'Dining': 1950,
#  'EdLife': 876,
#  'Editorial': 23437,
#  'Foreign': 11096,
#  'Games': 2105,
#  'Insider': 858,
#  'Learning': 4673,
#  'Letters': 39,
#  'Magazine': 5200,
#  'Metro': 2228,
#  'Metropolitan': 816,
#  'National': 72331,
#  'OpEd': 78957,
#  'Podcasts': 38,
#  'Politics': 1151,
#  'RealEstate': 155,
#  'Science': 4166,
#  'Sports': 2061,
#  'Styles': 50,
#  'SundayBusiness': 525,
#  'Travel': 538,
#  'Unknown': 3596,
#  'Upshot': 5075,
#  'Weekend': 154,
#  'Well': 1486}

# %%
comments_topic = []
n_comments = []

for i in range(len(comments_newDesk_group_list)):
    comments_topic.append(comments_newDesk_group_list[i][0])
    n_comments.append(comments_newDesk_group_list[i][1])

# %%
plt.close()
plt.figure(figsize=(10, 10))
plt.title("Number of Comments per Category")
plt.xlabel("Category")
plt.ylabel("Number of comments in each Topics")
plt.xticks(rotation=90)
sns.barplot(comments_topic, n_comments)
plt.show()

# %% [markdown]
# Compared to articles barplot, "OpEd" is much more greater than others.
#
# "Business" category is the third although the number of the articles of this topic is the 6th.
#
# I want to compare the number of comments and the number of articles from now.

# %%
df = pd.DataFrame.from_dict(comments_newDesk_group_dict, orient="index")

# %% [markdown]
# If this doesn't work, you can make dataframe at first, and then rename columns names.

# %%
df["number of articles"] = newDesk_group_dict.values()

# %%
df.head()
# Out:
#                 0  number of articles
# Sports       3240                  15
# Climate      3885                  11
# Dining       1722                  30
# Washington  51576                  74
# Foreign     15149                  56

# %%
w = 0.4
xtick = [i for i in range(len(df))]
xlabel = df.index

_, ax1 = plt.subplots(figsize=(20, 10))
ax1.bar(xtick, df["number of comments"], width=w/2, label='n of comments', align="center")
ax1.set_ylabel("n of comments")
plt.xticks(np.array(xtick) + w/2, xlabel, rotation=90)  
plt.legend(bbox_to_anchor=(1, 1))

ax2 = ax1.twinx()
ax2.bar(w /2 + np.array(xtick), df["number of articles"], width=w/2, color="orange", label='n of articles', align="center")
ax2.set_ylabel("n of articles")
plt.legend(bbox_to_anchor=(1, 0.95))

plt.title("number of comments and articles in each Topic")
plt.show()
plt.savefig("n_of_comments_articles.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number of comments'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-7aabd4132727> in <module>()
#       4
#       5 _, ax1 = plt.subplots(figsize=(20, 10))
# ----> 6 ax1.bar(xtick, df["number of comments"], width=w/2, label='n of comments', align="center")
#       7 ax1.set_ylabel("n of comments")
#       8 plt.xticks(np.array(xtick) + w/2, xlabel, rotation=90)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number of comments'

# %% [markdown]
# Seeing this plot, the number of comments relates to the number of articles to some extent.
#
# For example, "OpEd" and "Washington" have a large numbers respectively.

# %% [markdown]
# **Some stastitical analysis**

# %%
# I want to do some stastitical analysis.
CommentsAll_df["recommendations"].describe()
# Out:
# count     231449
# unique      1460
# top            0
# freq       36988
# Name: recommendations, dtype: object

# %%
plt.close()
plt.xlim(0, 200)
plt.title("The distribution of recommendations")
plt.xlabel("# of Recommendations")
plt.ylabel("# of Comments")
CommentsAll_df["recommendations"].hist(bins=max(CommentsAll_df["recommendations"]))
plt.grid(None)
plt.show()
# plt.savefig("recommend-dist.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d1a926d639f7> in <module>()
#       4 plt.xlabel("# of Recommendations")
#       5 plt.ylabel("# of Comments")
# ----> 6 CommentsAll_df["recommendations"].hist(bins=max(CommentsAll_df["recommendations"]))
#       7 plt.grid(None)
#       8 plt.show()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2198         values = self.dropna().values
#    2199
# -> 2200         ax.hist(values, bins=bins, **kwds)
#    2201         ax.grid(grid)
#    2202         axes = np.array([ax])
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6193             # this will automatically overwrite bins,
#    6194             # so that each histogram uses the same bins
# -> 6195             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6196             m = m.astype(float)  # causes problems later if it's an int
#    6197             if mlast is None:
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     660             mn, mx = 0.0, 1.0
#     661         else:
# --> 662             mn, mx = a.min() + 0.0, a.max() + 0.0
#     663     else:
#     664         mn, mx = [mi + 0.0 for mi in range]
#
# TypeError: must be str, not float
